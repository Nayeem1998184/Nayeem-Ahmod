# %%
import pandas as pd
import numpy as np
import scipy.stats as sp
import statsmodels.api as st
import matplotlib.pyplot as plt
loan=pd.read_csv(r'C:\Users\Nayee\OneDrive\Desktop\matplotlib\env\loan dataset.csv')

# %%
loan
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      Applicant_Income  Coapplican_Income  Loan_Amount  Loan_Amount_Term  \
# 0                5720                  0        110.0             360.0
# ...

# %%
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# Applicant_Income      0
# Coapplican_Income     0
# Loan_Amount           5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
loan1=loan.dropna()

# %%
loan1
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      Applicant_Income  Coapplican_Income  Loan_Amount  Loan_Amount_Term  \
# 0                5720                  0        110.0             360.0
# ...

# %%
loan1.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# Applicant_Income     0
# Coapplican_Income    0
# Loan_Amount          0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
loan1
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      Applicant_Income  Coapplican_Income  Loan_Amount  Loan_Amount_Term  \
# 0                5720                  0        110.0             360.0
# ...

# %%
qual=loan1.groupby('Gender')[['Married','Education']].nunique()

# %%
qual
# Out:
#         Married  Education
# Gender
# Female        2          2
# Male          2          2

# %%
relationship=pd.crosstab(index=loan1['Married'],columns='count')

# %%
relationship
# Out:
# col_0    count
# Married
# No         102
# Yes        187

# %%
property=pd.crosstab(index=loan1['Property_Area'],columns='count')

# %%
property
# Out:
# col_0          count
# Property_Area
# Rural             89
# Semiurban         87
# Urban            113

# %%
import pandas as pd 
import statsmodels.api as sm
x=loan1[['Applicant_Income','Coapplican_Income']]
y=loan1['Loan_Amount']
x=sm.add_constant(x)
model=sm.OLS(y,x).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            Loan_Amount   R-squared:                       0.271
# Model:                            OLS   Adj. R-squared:                  0.266
# Method:                 Least Squares   F-statistic:                     53.15
# Date:                Wed, 03 Jul 2024   Prob (F-statistic):           2.36e-20
# Time:                        11:09:44   Log-Likelihood:                -1545.7
# No. Observations:                 289   AIC:                             3097.
# Df Residuals:                     286   BIC:                             3108.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...
