# %%
#import data ,data cleaning,frequency ,data visialization,regression model 
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
#Import CSV
creditCard=pd.read_csv(r'C:\Users\Nayee\OneDrive\Desktop\matplotlib\env\credit card.csv')

# %%
creditCard
# Out:
#     checking_acc_status  duration  ... is_foreign_worker target
# 0               below_0         6  ...               yes   good
# 1             below_200        48  ...               yes    bad
# 2        no_cheking_acc        12  ...               yes   good
# 3               below_0        42  ...               yes   good
# 4               below_0        24  ...               yes    bad
# ..                  ...       ...  ...               ...    ...
# 995      no_cheking_acc        12  ...               yes   good
# 996             below_0        30  ...               yes   good
# 997      no_cheking_acc        12  ...               yes   good
# 998             below_0        45  ...               yes    bad
# 999           below_200        45  ...               yes   good
#
# [1000 rows x 21 columns]

# %%
#data cleaning 
creditCard.isnull().sum()
# Out:
# checking_acc_status         0
# duration                    0
# cred_hist                   0
# purpose                     0
# loan_amt                    0
# saving_acc_bonds            0
# present_employment_since    0
# installment_rate            0
# personal_stat_gender        0
# other_debtors_guarantors    0
# present_residence_since     0
# property                    0
# age                         0
# other_installment_plans     0
# housing                     0
# num_curr_loans              0
# job                         0
# num_people_provide_maint    0
# telephone                   0
# is_foreign_worker           0
# target                      0
# dtype: int64

# %%
creditCard.describe()
# Out:
#           duration      loan_amt  ...  num_curr_loans  num_people_provide_maint
# count  1000.000000   1000.000000  ...     1000.000000               1000.000000
# mean     20.903000   3271.258000  ...        1.407000                  1.155000
# std      12.058814   2822.736876  ...        0.577654                  0.362086
# min       4.000000    250.000000  ...        1.000000                  1.000000
# 25%      12.000000   1365.500000  ...        1.000000                  1.000000
# 50%      18.000000   2319.500000  ...        1.000000                  1.000000
# 75%      24.000000   3972.250000  ...        2.000000                  1.000000
# max      72.000000  18424.000000  ...        4.000000                  2.000000
#
# [8 rows x 7 columns]

# %%
creditCard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   checking_acc_status       1000 non-null   object
#  1   duration                  1000 non-null   int64
#  2   cred_hist                 1000 non-null   object
#  3   purpose                   1000 non-null   object
#  4   loan_amt                  1000 non-null   int64
#  5   saving_acc_bonds          1000 non-null   object
#  6   present_employment_since  1000 non-null   object
#  7   installment_rate          1000 non-null   int64
#  8   personal_stat_gender      1000 non-null   object
#  9   other_debtors_guarantors  1000 non-null   object
#  10  present_residence_since   1000 non-null   int64
#  11  property                  1000 non-null   object
#  12  age                       1000 non-null   int64
# ...

# %%
Job_fre=pd.crosstab(index=creditCard['job'],columns='count')

# %%
Job_fre
# Out:
# col_0                    count
# job
# management_or_self_emp     148
# skilled_official           630
# unemployed_non_resident     22
# unskilled_resident         200

# %%
purpose =pd.crosstab(index=creditCard['purpose'],columns='count')

# %%
purpose
# Out:
# col_0                count
# purpose
# business                97
# car_new                234
# car_used               103
# domestic_applience      12
# education               50
# furniture_equipment    181
# others                  12
# radio_tv               280
# repairs                 22
# retraining               9

# %%
Target=pd.crosstab(index=creditCard['target'],columns='count')

# %%
Target
# Out:
# col_0   count
# target
# bad       300
# good      700

# %%
Housing=pd.crosstab(index=creditCard['housing'],columns='count')

# %%
Housing
# Out:
# col_0     count
# housing
# for_free    108
# own         713
# rent        179

# %%
import matplotlib.pyplot as plt

labels = ['for_free','own','rent']
sizes = [108,713,179] 
plt.figure(figsize=(7, 7)) 
plt.pie(sizes, labels=labels,autopct='%1.1f%%') 
plt.axis('equal') 

plt.title('Housing')
plt.show()

# %%
gender=pd.crosstab(index=creditCard['personal_stat_gender'],columns='count')

# %%
gender
# Out:
# col_0                       count
# personal_stat_gender
# female:divorced_or_married    310
# male:divorced                  50
# male:married_or_widowed        92
# male:single                   548

# %%
import matplotlib.pyplot as plt
labels=['Female:divorced or married ','Male:divorcd','Male:married or widowed','Male:single']
sizes=[310,50,92,548]
plt.figure(figsize=(7,7))
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.axis('equal')
plt.title('Relationship Status')
plt.show()

# %%
purpose
# Out:
# col_0                count
# purpose
# business                97
# car_new                234
# car_used               103
# domestic_applience      12
# education               50
# furniture_equipment    181
# others                  12
# radio_tv               280
# repairs                 22
# retraining               9

# %%
import matplotlib.pyplot as plt
labels= ['Business','New Car Purchase','Used car Purchase','Domestic appliaces','Eduaction','Furniture','Other','Radio','Repairs','Retraining']
sizes=[97,234,103,12,50,181,12,280,22,9]
plt.figure(figsize=(7,7))
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.axis('equal')
plt.title('Purpose of Taking loan')
plt.show()

# %%
#simple reggresiion model 
creditCard
import pandas as pd 
import numpy as np 
import statsmodels.api as sm
x=creditCard['age','installment_rate']
y=creditCard['loan_amt']
x=sm.add_constant(x)
Model=sm.OLS(y,x).fit()
Model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #simple reggresiion model
# ----> 2 creditCard
#       3 import pandas as pd
#       4 import numpy as np
#
# NameError: name 'creditCard' is not defined
