# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\Nayee\OneDrive\Desktop\matplotlib\env\power_prediction.csv')

# %%
data.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
data.describe()
# Out:
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
#dependent and independent variable 
X=data.drop(columns=['PE'])
y=data['PE']

# %%
#trained data
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=1)

# %%
lin=LinearRegression()

# %%
model=lin.fit(X,y)

# %%
model
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-1.97751311, -0.23391642,  0.06208294, -0.1580541 ])

# %%
model.intercept_
# Out:
# 454.6092743153102

# %%
from sklearn.metrics import mean_absolute_error

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([459.39915416, 433.90061569, 474.86531662, ..., 477.30242019,
#        438.68889813, 444.46449632])

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3.587120219048918

# %%
import matplotlib.pyplot as plt
import seaborn as sp

# %%
coef_df=data.corr()



# Plotting the heatmap
plt.figure(figsize=(6, 8))
sp.heatmap(coef_df, annot=True, cmap='plasma', center=0)
plt.title('Model Coefficients Heatmap')
plt.show()
