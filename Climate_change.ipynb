# %%
import pandas as pd
import numpy as np

# %%
Climate=pd.read_csv(r'C:\Users\Nayee\OneDrive\Desktop\matplotlib\env\climate_change_impact_on_agriculture_2024.csv')

# %%
Climate.head()
# Out:
#    Year Country         Region  Crop_Type  Average_Temperature_C  \
# 0  2001   India    West Bengal       Corn                   1.55
# 1  2024   China          North       Corn                   3.23
# 2  2001  France  Ile-de-France      Wheat                  21.11
# 3  2001  Canada       Prairies     Coffee                  27.85
# 4  1998   India     Tamil Nadu  Sugarcane                   2.19
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
# 1                 2913.57             29.82                 1.737
# 2                 1301.74             25.75                 1.719
# 3                 1154.36             13.91                 3.890
# 4                 1627.48             11.81                 1.080
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
# ...

# %%
Climate.describe()
# Out:
#                Year  Average_Temperature_C  Total_Precipitation_mm  \
# count  10000.000000           10000.000000            10000.000000
# mean    2007.088700              15.241299             1611.663834
# std       10.084245              11.466955              805.016815
# min     1990.000000              -4.990000              200.150000
# 25%     1999.000000               5.430000              925.697500
# 50%     2007.000000              15.175000             1611.160000
# 75%     2016.000000              25.340000             2306.997500
# max     2024.000000              35.000000             2999.670000
#
#        CO2_Emissions_MT  Crop_Yield_MT_per_HA  Extreme_Weather_Events  \
# count      10000.000000          10000.000000            10000.000000
# mean          15.246608              2.240017                4.980900
# std            8.589423              0.998342                3.165808
# min            0.500000              0.450000                0.000000
# ...

# %%
Climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         10000 non-null  int64
#  1   Country                      10000 non-null  object
#  2   Region                       10000 non-null  object
#  3   Crop_Type                    10000 non-null  object
#  4   Average_Temperature_C        10000 non-null  float64
#  5   Total_Precipitation_mm       10000 non-null  float64
#  6   CO2_Emissions_MT             10000 non-null  float64
#  7   Crop_Yield_MT_per_HA         10000 non-null  float64
#  8   Extreme_Weather_Events       10000 non-null  int64
#  9   Irrigation_Access_%          10000 non-null  float64
#  10  Pesticide_Use_KG_per_HA      10000 non-null  float64
#  11  Fertilizer_Use_KG_per_HA     10000 non-null  float64
# ...

# %%
Climate.isnull().sum()
# Out:
# Year                           0
# Country                        0
# Region                         0
# Crop_Type                      0
# Average_Temperature_C          0
# Total_Precipitation_mm         0
# CO2_Emissions_MT               0
# Crop_Yield_MT_per_HA           0
# Extreme_Weather_Events         0
# Irrigation_Access_%            0
# Pesticide_Use_KG_per_HA        0
# Fertilizer_Use_KG_per_HA       0
# Soil_Health_Index              0
# Adaptation_Strategies          0
# Economic_Impact_Million_USD    0
# dtype: int64

# %%
Climate=Climate.rename(columns={'Fertilizer_Use_KG_per_HA':'Fert_use','Adaptation_Strategies':'Adapt_stg',
                                'Average_Temperature_C' :'Avg_tempC',
                                'Pesticide_Use_KG_per_HA':'pestC_use_kgha',
                                'Economic_Impact_Million_USD':'Economic_impact',
                               'Extreme_Weather_Events':'Ext_weather_event'})

# %%
Climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    10000 non-null  int64
#  1   Country                 10000 non-null  object
#  2   Region                  10000 non-null  object
#  3   Crop_Type               10000 non-null  object
#  4   Avg_tempC               10000 non-null  float64
#  5   Total_Precipitation_mm  10000 non-null  float64
#  6   CO2_Emissions_MT        10000 non-null  float64
#  7   Crop_Yield_MT_per_HA    10000 non-null  float64
#  8   Ext_weather_event       10000 non-null  int64
#  9   Irrigation_Access_%     10000 non-null  float64
#  10  pestC_use_kgha          10000 non-null  float64
#  11  Fert_use                10000 non-null  float64
#  12  Soil_Health_Index       10000 non-null  float64
#  13  Adapt_stg               10000 non-null  object
# ...

# %%
Climate=Climate.drop(columns=['Year'])

# %%
Climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 10000 non-null  object
#  1   Region                  10000 non-null  object
#  2   Crop_Type               10000 non-null  object
#  3   Avg_tempC               10000 non-null  float64
#  4   Total_Precipitation_mm  10000 non-null  float64
#  5   CO2_Emissions_MT        10000 non-null  float64
#  6   Crop_Yield_MT_per_HA    10000 non-null  float64
#  7   Ext_weather_event       10000 non-null  int64
#  8   Irrigation_Access_%     10000 non-null  float64
#  9   pestC_use_kgha          10000 non-null  float64
#  10  Fert_use                10000 non-null  float64
#  11  Soil_Health_Index       10000 non-null  float64
#  12  Adapt_stg               10000 non-null  object
#  13  Economic_impact         10000 non-null  float64
# ...

# %%
Country=pd.crosstab(index=Climate['Country'],columns='total')

# %%
Country
# Out:
# col_0      total
# Country
# Argentina    984
# Australia   1032
# Brazil       944
# Canada       984
# China       1031
# France       978
# India       1025
# Nigeria     1029
# Russia       961
# USA         1032

# %%
adapt_stg=pd.crosstab(index=Climate['Adapt_stg'],columns='total')

# %%
adapt_stg
# Out:
# col_0                    total
# Adapt_stg
# Crop Rotation             1957
# Drought-resistant Crops   1995
# No Adaptation             2024
# Organic Farming           1975
# Water Management          2049

# %%
ag=Climate.groupby('Country').agg({'Economic_imp':sum,'Avg_tempC':sum,'pestC_use_kgha':sum})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 ag=Climate.groupby('Country').agg({'Economic_imp':sum,'Avg_tempC':sum,'pestC_use_kgha':sum})
#
# File c:\Users\Nayee\OneDrive\Desktop\matplotlib\env\lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\Users\Nayee\OneDrive\Desktop\matplotlib\env\lib\site-packages\pandas\core\apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
# ...

# %%
ag
# Out:
#            Economic_imp  Avg_tempC  pestC_use_kgha
# Country
# Argentina     663271.04   15170.13        24927.09
# Australia     682067.12   15666.80        25538.00
# Brazil        637327.76   14527.43        23339.61
# Canada        669239.98   15128.32        24629.80
# China         695605.22   16195.55        26193.45
# France        648634.54   15060.55        23955.03
# India         700497.99   15039.70        26171.59
# Nigeria       719560.30   15193.42        25904.08
# Russia        640153.73   14253.58        23329.62
# USA           686338.90   16177.51        25569.08

# %%
pt=Climate.pivot_table(index='Country',values='Economic_imp',aggfunc= 'mean')

# %%
pt
# Out:
#            Economic_imp
# Country
# Argentina    674.055935
# Australia    660.917752
# Brazil       675.135339
# Canada       680.121931
# China        674.689835
# France       663.225501
# India        683.412673
# Nigeria      699.281147
# Russia       666.132914
# USA          665.057074

# %%
pt2=Climate.pivot_table(index='Country',values=('Avg_tempC','Economic_imp'),aggfunc='mean')

# %%
pt2
# Out:
#            Avg_tempC  Economic_imp
# Country
# Argentina  15.416799    674.055935
# Australia  15.181008    660.917752
# Brazil     15.389227    675.135339
# Canada     15.374309    680.121931
# China      15.708584    674.689835
# France     15.399335    663.225501
# India      14.672878    683.412673
# Nigeria    14.765228    699.281147
# Russia     14.832029    666.132914
# USA        15.675882    665.057074

# %%
Climate['Adapt_stg'].hist(figsize=(10,10),)
# Out:
# <Axes: >

# %%
Climate.boxplot(column=['Economic_imp','Fert_use'],figsize=(15,15))
# Out:
# <Axes: >

# %%
Climate.columns
# Out:
# Index(['Country', 'Region', 'Crop_Type', 'Avg_tempC', 'Total_Precipitation_mm',
#        'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA', 'Ext_weather_event',
#        'Irrigation_Access_%', 'pestC_use_kgha', 'Fert_use',
#        'Soil_Health_Index', 'Adapt_stg', 'Economic_imp'],
#       dtype='object')

# %%
Climate.plot.scatter(
    y='Economic_imp',
    x='Country'
    
)
# Out:
# <Axes: xlabel='Country', ylabel='Economic_imp'>

# %%
Climate.columns
# Out:
# Index(['Avg_tempC', 'Total_Precipitation_mm', 'CO2_Emissions_MT',
#        'Crop_Yield_MT_per_HA', 'Ext_weather_event', 'Irrigation_Access_%',
#        'pestC_use_kgha', 'Fert_use', 'Soil_Health_Index', 'Adapt_stg',
#        'Economic_imp'],
#       dtype='object')

# %%
climate=Climate.drop(columns=['Adapt_stg'])
climate.head()
# Out:
#    Avg_tempC  Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0       1.55                  447.06             15.22                 1.737
# 1       3.23                 2913.57             29.82                 1.737
# 2      21.11                 1301.74             25.75                 1.719
# 3      27.85                 1154.36             13.91                 3.890
# 4       2.19                 1627.48             11.81                 1.080
#
#    Ext_weather_event  Irrigation_Access_%  pestC_use_kgha  Fert_use  \
# 0                  8                14.54           10.08     14.78
# 1                  8                11.05           33.06     23.25
# 2                  5                84.42           27.41     65.53
# 3                  5                94.06           14.38     87.58
# 4                  9                95.75           44.35     88.08
#
#    Soil_Health_Index  Economic_imp
# 0              83.25        808.13
# ...

# %%
climate.corr()
# Out:
#                         Avg_tempC  Total_Precipitation_mm  CO2_Emissions_MT  \
# Avg_tempC                1.000000                0.007213         -0.003052
# Total_Precipitation_mm   0.007213                1.000000         -0.008681
# CO2_Emissions_MT        -0.003052               -0.008681          1.000000
# Crop_Yield_MT_per_HA     0.263781                0.029728         -0.089868
# Ext_weather_event       -0.016808                0.004360          0.001255
# Irrigation_Access_%     -0.013268               -0.007580          0.002995
# pestC_use_kgha           0.005764                0.011198          0.015243
# Fert_use                -0.014725               -0.026356         -0.020275
# Soil_Health_Index       -0.010841               -0.021621          0.004518
# Economic_imp             0.195827                0.020966         -0.057035
#
#                         Crop_Yield_MT_per_HA  Ext_weather_event  \
# Avg_tempC                           0.263781          -0.016808
# ...

# %%
climate.cov()
# Out:
#                          Avg_tempC  Total_Precipitation_mm  CO2_Emissions_MT  \
# Avg_tempC               131.491048               66.583786         -0.300631
# Total_Precipitation_mm   66.583786           648052.072133        -60.023301
# CO2_Emissions_MT         -0.300631              -60.023301         73.778186
# Crop_Yield_MT_per_HA      3.019745               23.891458         -0.770636
# Ext_weather_event        -0.610180               11.111491          0.034126
# Irrigation_Access_%      -3.954098             -158.589855          0.668639
# pestC_use_kgha            0.957756              130.625388          1.897223
# Fert_use                 -4.847970             -609.157033         -5.000038
# Soil_Health_Index        -2.510625             -351.508885          0.783698
# Economic_imp            930.982207             6997.347804       -203.107977
#
#                         Crop_Yield_MT_per_HA  Ext_weather_event  \
# ...

# %%
climate.head()
# Out:
#    Avg_tempC  Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0       1.55                  447.06             15.22                 1.737
# 1       3.23                 2913.57             29.82                 1.737
# 2      21.11                 1301.74             25.75                 1.719
# 3      27.85                 1154.36             13.91                 3.890
# 4       2.19                 1627.48             11.81                 1.080
#
#    Ext_weather_event  Irrigation_Access_%  pestC_use_kgha  Fert_use  \
# 0                  8                14.54           10.08     14.78
# 1                  8                11.05           33.06     23.25
# 2                  5                84.42           27.41     65.53
# 3                  5                94.06           14.38     87.58
# 4                  9                95.75           44.35     88.08
#
#    Soil_Health_Index  Economic_imp
# 0              83.25        808.13
# ...

# %%
import matplotlib .pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.scatter(x=Climate['Country'],y=Climate['Economic_impact'],color='blue',marker='*')
plt.xlabel('country')
plt.ylabel('Economic_affect')
plt.title('Economic_impact_by_country')
plt.show()

# %%
plt.figure(figsize=(10,5))
Categories=Climate['Country']
Values=Climate['CO2_Emissions_MT']
plt.bar(Categories,Values,color='green')
plt.title('CO2_emitted_By_countries',color='blue')
plt.xlabel('Countries',color='Red')
plt.ylabel('CO2',color='green')
# Out:
# Text(0, 0.5, 'CO2')

# %%
import matplotlib.pyplot as plt
labels=Climate['Country']
sizes=Climate['CO2_Emissions_MT']
plt.pie(sizes,labels=labels,autopct='%1.1F%%')
plt.title('CO2_Emmited by countries')
# Out:
# Text(0.5, 1.0, 'CO2_Emmited by countries')

# %%
X=Climate['Avg_tempC']

# %%
plt.hist(X,bins=5,edgecolor='k',color='purple')
plt.xlabel('Temperature')
plt.ylabel('Frequecy')
# Out:
# Text(0, 0.5, 'Frequecy')

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x=Climate['Country'],y=Climate['Avg_tempC'],color='Blue')
plt.xlabel('Country',color='green')
plt.ylabel('Temperature',color='purple')
plt.title('Countries_produced_Co2',color='Orange')
# Out:
# Text(0.5, 1.0, 'Countries_produced_Co2')

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=Climate['Country'],y=Climate['Avg_tempC'],color='Blue',marker='+')
plt.xlabel('Country',color='green')
plt.ylabel('Temperature',color='purple')
plt.title('Countries_produced_Co2',color='Orange')
# Out:
# Text(0.5, 1.0, 'Countries_produced_Co2')

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=Climate['Country'],y=Climate['Avg_tempC'],color='Blue')
plt.xlabel('Country',color='green')
plt.ylabel('Temperature',color='purple')
plt.title('Countries_produced_Co2',color='Orange')
# Out:
# Text(0.5, 1.0, 'Countries_produced_Co2')

# %%
sns.histplot(x=Climate['Crop_Yield_MT_per_HA'],bins=5,edgecolor='k')
plt.xlabel('Crop')
plt.ylabel('Frequency')
plt.title('Crop_yield_frequency')
# Out:
# Text(0.5, 1.0, 'Crop_yield_frequency')

# %%
plt.figure(figsize=(10,10))
sns.boxenplot(x=Climate['Country'],
              y=Climate['pestC_use_kgha'])
plt.xlabel('Country')
plt.ylabel('Used_Pest')
# Out:
# Text(0, 0.5, 'Used_Pest')

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x=Climate['Country'],
              y=Climate['pestC_use_kgha'])
plt.xlabel('Country')
plt.ylabel('Used_Pest')
# Out:
# Text(0, 0.5, 'Used_Pest')

# %%
Climate.head()
# Out:
#   Country         Region  Crop_Type  Avg_tempC  Total_Precipitation_mm  \
# 0   India    West Bengal       Corn       1.55                  447.06
# 1   China          North       Corn       3.23                 2913.57
# 2  France  Ile-de-France      Wheat      21.11                 1301.74
# 3  Canada       Prairies     Coffee      27.85                 1154.36
# 4   India     Tamil Nadu  Sugarcane       2.19                 1627.48
#
#    CO2_Emissions_MT  Crop_Yield_MT_per_HA  Ext_weather_event  \
# 0             15.22                 1.737                  8
# 1             29.82                 1.737                  8
# 2             25.75                 1.719                  5
# 3             13.91                 3.890                  5
# 4             11.81                 1.080                  9
#
#    Irrigation_Access_%  pestC_use_kgha  Fert_use  Soil_Health_Index  \
# 0                14.54           10.08     14.78              83.25
# ...

# %%
Climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 10000 non-null  object
#  1   Region                  10000 non-null  object
#  2   Crop_Type               10000 non-null  object
#  3   Avg_tempC               10000 non-null  float64
#  4   Total_Precipitation_mm  10000 non-null  float64
#  5   CO2_Emissions_MT        10000 non-null  float64
#  6   Crop_Yield_MT_per_HA    10000 non-null  float64
#  7   Ext_weather_event       10000 non-null  int64
#  8   Irrigation_Access_%     10000 non-null  float64
#  9   pestC_use_kgha          10000 non-null  float64
#  10  Fert_use                10000 non-null  float64
#  11  Soil_Health_Index       10000 non-null  float64
#  12  Adapt_stg               10000 non-null  object
#  13  Economic_impact         10000 non-null  float64
# ...

# %%
climate = Climate.drop(columns=['Country', 'Adapt_stg', 'Region', 'Crop_Type'])

# %%
climate.head()
# Out:
#    Avg_tempC  Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0       1.55                  447.06             15.22                 1.737
# 1       3.23                 2913.57             29.82                 1.737
# 2      21.11                 1301.74             25.75                 1.719
# 3      27.85                 1154.36             13.91                 3.890
# 4       2.19                 1627.48             11.81                 1.080
#
#    Ext_weather_event  Irrigation_Access_%  pestC_use_kgha  Fert_use  \
# 0                  8                14.54           10.08     14.78
# 1                  8                11.05           33.06     23.25
# 2                  5                84.42           27.41     65.53
# 3                  5                94.06           14.38     87.58
# 4                  9                95.75           44.35     88.08
#
#    Soil_Health_Index  Economic_impact
# 0              83.25           808.13
# ...

# %%
sns.pairplot(data=climate,hue='Economic_impact')

# %%
data=climate.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 8))
sns.heatmap(data, annot=True, cmap='viridis')  
plt.title('Heatmap', fontdict={'color': 'red'})  
plt.show()

# %%
climate.describe()
# Out:
#           Avg_tempC  Total_Precipitation_mm  CO2_Emissions_MT  \
# count  10000.000000            10000.000000      10000.000000
# mean      15.241299             1611.663834         15.246608
# std       11.466955              805.016815          8.589423
# min       -4.990000              200.150000          0.500000
# 25%        5.430000              925.697500          7.760000
# 50%       15.175000             1611.160000         15.200000
# 75%       25.340000             2306.997500         22.820000
# max       35.000000             2999.670000         30.000000
#
#        Crop_Yield_MT_per_HA  Ext_weather_event  Irrigation_Access_%  \
# count          10000.000000       10000.000000         10000.000000
# mean               2.240017           4.980900            55.248332
# std                0.998342           3.165808            25.988305
# min                0.450000           0.000000            10.010000
# ...

# %%
corR=climate.corr()

# %%
corR
# Out:
#                         Avg_tempC  Total_Precipitation_mm  CO2_Emissions_MT  \
# Avg_tempC                1.000000                0.007213         -0.003052
# Total_Precipitation_mm   0.007213                1.000000         -0.008681
# CO2_Emissions_MT        -0.003052               -0.008681          1.000000
# Crop_Yield_MT_per_HA     0.263781                0.029728         -0.089868
# Ext_weather_event       -0.016808                0.004360          0.001255
# Irrigation_Access_%     -0.013268               -0.007580          0.002995
# pestC_use_kgha           0.005764                0.011198          0.015243
# Fert_use                -0.014725               -0.026356         -0.020275
# Soil_Health_Index       -0.010841               -0.021621          0.004518
# Economic_impact          0.195827                0.020966         -0.057035
#
#                         Crop_Yield_MT_per_HA  Ext_weather_event  \
# Avg_tempC                           0.263781          -0.016808
# ...

# %%
cOv=climate.cov()

# %%
cOv
# Out:
#                          Avg_tempC  Total_Precipitation_mm  CO2_Emissions_MT  \
# Avg_tempC               131.491048               66.583786         -0.300631
# Total_Precipitation_mm   66.583786           648052.072133        -60.023301
# CO2_Emissions_MT         -0.300631              -60.023301         73.778186
# Crop_Yield_MT_per_HA      3.019745               23.891458         -0.770636
# Ext_weather_event        -0.610180               11.111491          0.034126
# Irrigation_Access_%      -3.954098             -158.589855          0.668639
# pestC_use_kgha            0.957756              130.625388          1.897223
# Fert_use                 -4.847970             -609.157033         -5.000038
# Soil_Health_Index        -2.510625             -351.508885          0.783698
# Economic_impact         930.982207             6997.347804       -203.107977
#
#                         Crop_Yield_MT_per_HA  Ext_weather_event  \
# ...

# %%
Climate['Country'].value_counts()
# Out:
# Country
# USA          1032
# Australia    1032
# China        1031
# Nigeria      1029
# India        1025
# Canada        984
# Argentina     984
# France        978
# Russia        961
# Brazil        944
# Name: count, dtype: int64

# %%
Climate.columns
# Out:
# Index(['Country', 'Region', 'Crop_Type', 'Avg_tempC', 'Total_Precipitation_mm',
#        'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA', 'Ext_weather_event',
#        'Irrigation_Access_%', 'pestC_use_kgha', 'Fert_use',
#        'Soil_Health_Index', 'Adapt_stg', 'Economic_impact'],
#       dtype='object')

# %%
uk=Climate['Adapt_stg'].nunique()

# %%
uk
# Out:
# 5

# %%
contry=Climate['Country'].nunique()

# %%
contry
# Out:
# 10

# %%
pair=Climate[['Adapt_stg','Country']]

# %%
pair
# Out:
#              Adapt_stg    Country
# 0     Water Management      India
# 1        Crop Rotation      China
# 2     Water Management     France
# 3        No Adaptation     Canada
# 4        Crop Rotation      India
# ...                ...        ...
# 9995     No Adaptation     France
# 9996     No Adaptation  Australia
# 9997  Water Management  Argentina
# 9998     Crop Rotation     Brazil
# 9999  Water Management      China
#
# [10000 rows x 2 columns]

# %%
loc=Climate.loc[0:100]

# %%
loc
# Out:
#        Country             Region  Crop_Type  Avg_tempC  \
# 0        India        West Bengal       Corn       1.55
# 1        China              North       Corn       3.23
# 2       France      Ile-de-France      Wheat      21.11
# 3       Canada           Prairies     Coffee      27.85
# 4        India         Tamil Nadu  Sugarcane       2.19
# ..         ...                ...        ...        ...
# 96      Russia            Central     Fruits      13.20
# 97     Nigeria         South East     Barley      15.75
# 98   Australia  Western Australia   Soybeans       1.57
# 99     Nigeria         North West       Corn      32.28
# 100      India             Punjab   Soybeans      12.14
#
#      Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                    447.06             15.22                 1.737
# 1                   2913.57             29.82                 1.737
# 2                   1301.74             25.75                 1.719
# ...

# %%
con=Climate[Climate['Economic_impact']>1500]

# %%
con
# Out:
#         Country       Region  Crop_Type  Avg_tempC  Total_Precipitation_mm  \
# 15       France    Grand Est   Soybeans      15.23                 1468.76
# 19       Russia     Siberian     Cotton      19.20                 1086.11
# 21        India  West Bengal   Soybeans      14.00                 1240.49
# 36       Brazil        North  Sugarcane      14.69                  804.11
# 55       Canada       Quebec     Cotton      32.58                 2162.09
# ...         ...          ...        ...        ...                     ...
# 9890  Argentina    Patagonia      Wheat      18.20                 1927.17
# 9943     Russia     Siberian       Corn      19.47                 1352.23
# 9964        USA         West     Barley      14.81                  747.56
# 9985      India       Punjab     Coffee      16.69                  737.41
# 9998     Brazil    Southeast   Soybeans      13.95                 1549.52
#
#       CO2_Emissions_MT  Crop_Yield_MT_per_HA  Ext_weather_event  \
# ...

# %%
crop=Climate['Crop_Type'].value_counts()

# %%
crop
# Out:
# Crop_Type
# Wheat         1047
# Cotton        1044
# Vegetables    1036
# Corn          1022
# Rice          1022
# Sugarcane      995
# Fruits         979
# Soybeans       958
# Barley         952
# Coffee         945
# Name: count, dtype: int64

# %%
q=Climate.query('Economic_impact>2300')

# %%
q
# Out:
#      Country    Region  Crop_Type  Avg_tempC  Total_Precipitation_mm  \
# 4704   India    Punjab  Sugarcane      19.92                 1248.01
# 6763  Russia  Siberian     Barley      13.95                 2110.20
#
#       CO2_Emissions_MT  Crop_Yield_MT_per_HA  Ext_weather_event  \
# 4704              6.12                  4.96                  6
# 6763              4.59                  4.80                  4
#
#       Irrigation_Access_%  pestC_use_kgha  Fert_use  Soil_Health_Index  \
# 4704                67.09           30.13     64.61              83.45
# 6763                82.51            3.85     29.67              51.47
#
#             Adapt_stg  Economic_impact
# 4704  Organic Farming          2346.47
# 6763    Crop Rotation          2312.29

# %%
Climate['Crop_Yield_MT_per_HA'].shift(1)
# Out:
# 0         NaN
# 1       1.737
# 2       1.737
# 3       1.719
# 4       3.890
#         ...
# 9995    3.010
# 9996    3.033
# 9997    2.560
# 9998    1.161
# 9999    3.348
# Name: Crop_Yield_MT_per_HA, Length: 10000, dtype: float64
